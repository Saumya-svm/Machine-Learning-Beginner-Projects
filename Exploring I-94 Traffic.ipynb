# %% [markdown]
# # Exploring I-94 traffic.We cn get the dataset [here](https://archive.ics.uci.edu/ml/datasets/Metro+Interstate+Traffic+Volume)

# %%
import pandas as pd
traffic = pd.read_csv("Metro_Interstate_Traffic_Volume.csv")

# %%
traffic.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
traffic.head(50)
# Out:
#    holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     None  288.28      0.0      0.0          40       Clouds
# 1     None  289.36      0.0      0.0          75       Clouds
# 2     None  289.58      0.0      0.0          90       Clouds
# 3     None  290.13      0.0      0.0          90       Clouds
# 4     None  291.14      0.0      0.0          75       Clouds
# 5     None  291.72      0.0      0.0           1        Clear
# 6     None  293.17      0.0      0.0           1        Clear
# 7     None  293.86      0.0      0.0           1        Clear
# 8     None  294.14      0.0      0.0          20       Clouds
# 9     None  293.10      0.0      0.0          20       Clouds
# 10    None  290.97      0.0      0.0          20       Clouds
# 11    None  289.38      0.0      0.0           1        Clear
# 12    None  288.61      0.0      0.0           1        Clear
# 13    None  287.16      0.0      0.0           1        Clear
# ...

# %% [markdown]
# As we can see, there is some irregularity in the data at the 23rd column. We will try to correct it only if it has occured substantially.

# %%
traffic.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48199    None  283.45      0.0      0.0          75        Clouds
# 48200    None  282.76      0.0      0.0          90        Clouds
# 48201    None  282.73      0.0      0.0          90  Thunderstorm
# 48202    None  282.09      0.0      0.0          90        Clouds
# 48203    None  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume
# 48199           broken clouds  2018-09-30 19:00:00            3543
# 48200         overcast clouds  2018-09-30 20:00:00            2781
# 48201  proximity thunderstorm  2018-09-30 21:00:00            2159
# 48202         overcast clouds  2018-09-30 22:00:00            1450
# 48203         overcast clouds  2018-09-30 23:00:00             954

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
traffic_volume = traffic['traffic_volume']
traffic_volume.plot.hist()

# %%
traffic_volume.describe()
# Out:
# count    48204.000000
# mean      3259.818355
# std       1986.860670
# min          0.000000
# 25%       1193.000000
# 50%       3380.000000
# 75%       4933.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# - The count in <b>'traffic_volume'</b> is same as the total number of rows in the dataframe.
# - The average volume of cars each hour is around <b>3260</b>. This is for around 50 % of the time.
# - Traffic has surged to high levels, more than the double of the average volume
# - For 25% of the time, there were around 1200 cars and also, for the same amount of time, the traffic volume was four times of the former volume.
#
#
#
# The most direct comparison for the staggering difference in traffic volume can be done by comparing the data at daytime and nighttime.
#
# We can divide the day as follows-
# - <b>7AM to 7PM</b> (daytime)
# - <b>7PM to 7AM</b> (nightime)

# %%
traffic['date_time'] = pd.to_datetime(traffic['date_time'])
traffic['date_time'].dt.hour
# Out:
# 0         9
# 1        10
# 2        11
# 3        12
# 4        13
#          ..
# 48199    19
# 48200    20
# 48201    21
# 48202    22
# 48203    23
# Name: date_time, Length: 48204, dtype: int64

# %%
traffic_day = traffic.loc[(traffic['date_time'].dt.hour >=7)
                          & (traffic['date_time'].dt.hour < 19),
                          "traffic_volume"]
day = traffic.copy()[(traffic['date_time'].dt.hour >=7)
                          & (traffic['date_time'].dt.hour < 19)]

# %%
traffic_day
# Out:
# 0        5545
# 1        4516
# 2        4767
# 3        5026
# 4        4918
#          ...
# 48194    4302
# 48195    4302
# 48196    4283
# 48197    4132
# 48198    3947
# Name: traffic_volume, Length: 23877, dtype: int64

# %%
traffic_night = traffic.loc[(traffic['date_time'].dt.hour >=19)
                          | (traffic['date_time'].dt.hour < 7),
                          "traffic_volume"]
night = traffic.copy()[(traffic['date_time'].dt.hour >=19)
                          | (traffic['date_time'].dt.hour < 7)]

# %%
traffic_night
# Out:
# 10       3539
# 11       2784
# 12       2361
# 13       1529
# 14        963
#          ...
# 48199    3543
# 48200    2781
# 48201    2159
# 48202    1450
# 48203     954
# Name: traffic_volume, Length: 24327, dtype: int64

# %%
print(traffic_day.shape, traffic_night.shape)
# Out:
# (23877,) (24327,)

# %% [markdown]
# As we can see, there is a difference between the shape or number o fnetries in the daytime and nightime. This is due to missing hours in our data. As mentioned in a cell above, the data after 23rd columns are missing. By default these data were supposed to contribute to the daytime rows.

# %%
plt.figure(figsize = (12,4))

plt.subplot(1,2,1)
plt.hist(traffic_day)
plt.xlim(0, 7500)
plt.ylim(0, 8000)
plt.title('Traffic Volume: Day')
plt.ylabel('Frequency')
plt.xlabel('Traffic Volume')

plt.subplot(1,2,2)
plt.hist(traffic_night)
plt.xlim(0, 7500)
plt.ylim(0, 8000)
plt.title('Traffic Volume: Night')
plt.ylabel('Frequency')
plt.xlabel('Traffic Volume')
# Out:
# Text(0.5, 0, 'Traffic Volume')

# %%
traffic_day.describe()
# Out:
# count    23877.000000
# mean      4762.047452
# std       1174.546482
# min          0.000000
# 25%       4252.000000
# 50%       4820.000000
# 75%       5559.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %%
traffic_night.describe()
# Out:
# count    24327.000000
# mean      1785.377441
# std       1441.951197
# min          0.000000
# 25%        530.000000
# 50%       1287.000000
# 75%       2819.000000
# max       6386.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# - Analysing from the cells above, the average hourly traffic volume for daytime is <b>4820</b> 10/3 times of the nightime, <b>1287</b>.
# - The histogram of daytime traffic volume is left skewed, implying that most of the traffic volume are high values. About 75 % of the time the cars are more than <b>4252</b>.
# - Whereas the histogram of the nightime volume. is left skewed, implying most of its traffic volume is less. About 75 % of time the cars are less than <b>2819</b>.
# - For 25% of time, daytime volume is <b>8</b> times of the nightime.Also, for the same amount of time, in a different scenario, daytime volume is <b>2</b> times of the nightime.
# - Overall the daytime traffic volume is heavy and the nightime traffic is light.

# %% [markdown]
# Our goal is to find indicators of heavy traffic, so we decide to only focus on the daytime data from here on.

# %%
day['month'] = day['date_time'].dt.month
by_month = day.groupby('month').mean()
by_month['traffic_volume']
# Out:
# month
# 1     4495.613727
# 2     4711.198394
# 3     4889.409560
# 4     4906.894305
# 5     4911.121609
# 6     4898.019566
# 7     4595.035744
# 8     4928.302035
# 9     4870.783145
# 10    4921.234922
# 11    4704.094319
# 12    4374.834566
# Name: traffic_volume, dtype: float64

# %%
by_month['traffic_volume'].plot.line()

# %% [markdown]
# The traffic volume is low during the winter months(Nov-Feb) while it is high during the summmer months(March-Oct).
# There is one exception in month og July where the volume has dropped uncharacteristically.
#
#
# We can check if there is any event or factor which causes the average traffic volume to drop in July.
#
# Below we plot the average traffic volume in JULY for each year of the data.

# %%
day['year'] = day['date_time'].dt.year
only_july = day[day['month'] == 7]
only_july.groupby('year').mean()['traffic_volume'].plot.line()
plt.show()

# %% [markdown]
# As seen, the decrease was more specific to 2016.
# As stated in this [report](https://dot.state.mn.us/traffic/data/reports/atr/Monthly_PDFs/Jan18/301.pdf), the downwards spike was due to construction.
#
#
# Now, to conclude the monthly analysis, the warm months show a high traffic volume as compared to cold months, at nearly 5000 hourly cars.

# %% [markdown]
# We will now analyse using a more fundamental metric than month, that is by days of the weeks.

# %%
day['dayofweek'] = day['date_time'].dt.dayofweek
by_dayofweek = day.groupby('dayofweek').mean()
by_dayofweek['traffic_volume']
# Out:
# dayofweek
# 0    4893.551286
# 1    5189.004782
# 2    5284.454282
# 3    5311.303730
# 4    5291.600829
# 5    3927.249558
# 6    3436.541789
# Name: traffic_volume, dtype: float64

# %%
by_dayofweek['traffic_volume'].plot.line()

# %% [markdown]
# - As seen, the volume during weekdays is significantly higher than that on the weekends.
# - The volume on the weekends is below 4000 whereas on the weekdays, the values are above 5000, except for Monday as the value is just below 5000.
#
#
# Now we will analyse an even more fundametric, time of the each day

# %%
day['hour'] = day['date_time'].dt.hour
bussiness_days = day.copy()[day['dayofweek'] <= 4] # 4 == Friday
weekend = day.copy()[day['dayofweek'] >= 5] # 5 = Saturday
by_hour_business = bussiness_days.groupby('hour').mean()
by_hour_weekend = weekend.groupby('hour').mean()


plt.figure(figsize=(11,3.5))

plt.subplot(1, 2, 1)
by_hour_business['traffic_volume'].plot.line()
plt.xlim(6,20)
plt.ylim(1500,6500)
plt.title('Traffic Volume By Hour: Monday–Friday')

plt.subplot(1, 2, 2)
by_hour_weekend['traffic_volume'].plot.line()
plt.xlim(6,20)
plt.ylim(1500,6500)
plt.title('Traffic Volume By Hour: Weekend')

plt.show()

# %% [markdown]
# - For the same time, the traffic volume is more on the weekdays.
# - During the weekdays,the volume is more when people attend and leave their work at around 7AM and 4-5 PM respectively.
# - The less volume on weekend mornings is basically due to less urgency to work and it increases during midday, maybe due to weekend holidays, personal leisure or non-work related stuff.

# %% [markdown]
# To conclude our analysis of effects of time metrics on traffic volume are as follows-
#
# - The volume is high during warm months as compared to cold months.
# - The traffic during daytime is substantially higher than nightime.
# - The traffic is heigher on business days and that too during arrival and departure from work.

# %% [markdown]
# ## Weather Indicators
#
# Having focused on time indicators for heavy traffic, we will now analyse the weather topic. We have many columns about weather types in dataframe.

# %%
day.corr()["traffic_volume"]
# Out:
# temp              0.128317
# rain_1h           0.003697
# snow_1h           0.001265
# clouds_all       -0.032932
# traffic_volume    1.000000
# month            -0.022337
# year             -0.003557
# dayofweek        -0.416453
# hour              0.172704
# Name: traffic_volume, dtype: float64

# %% [markdown]
# Among the weather based columns, the <b>temp</b> column has the strongest correlation with traffic_volume.

# %%
day.plot.scatter('traffic_volume', 'temp')
plt.ylim(235, 320)
plt.show()

# %% [markdown]
# There is no type of correlation between traffic_volume and temp

# %%
day.plot.scatter('traffic_volume', 'rain_1h')
plt.show()

# %%
day.plot.scatter('traffic_volume', 'snow_1h')
plt.show()

# %%
day.plot.scatter('traffic_volume', 'clouds_all')

# %% [markdown]
# There is no correlation of volume with any parameters
#
# We will have to look at the categorical weather related columns because we dont have any correlation with numerical based columns

# %%
by_weather_main = day.groupby('weather_main').mean()
by_weather_main['traffic_volume'].plot.barh()
plt.show()

# %%
by_weather_main = day.groupby('weather_description').mean()
by_weather_main['traffic_volume'].plot.barh(figsize = (9,15))
plt.show()

# %% [markdown]
# Weather types exceed 5000 only for three weather types -
# - Shower snow
# - Light rain and snow
# - Proximity thunderstorm with drizzle

# %% [markdown]
# ## Conclusion
#
# Time Indicators-
# - The volume is high during warm months as compared to cold months.
# - The traffic during daytime is substantially higher than nightime.
# - The traffic is heigher on business days and that too during arrival and departure from work.
#
# Weather Indicators -
# - Shower snow
# - Light rain and snow
# - Proximity thunderstorm with drizzle
